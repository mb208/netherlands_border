# %%
from utils.db_connect import query

# %%
query("SELECT * FROM rws_raw.interfaces_intensiteit LIMIT 10")
# Out:
#       measurementsitereference measurementsiteversion index  \
# 0  RWS01_MONIBAS_0071hrl2516ra                      1    9B
# 1  RWS01_MONIBAS_0071hrl2516ra                      1   10B
# 2  RWS01_MONIBAS_0071hrl2516ra                      1   11B
# 3  RWS01_MONIBAS_0071hrl2516ra                      1   12B
# 4  RWS01_MONIBAS_0071hrr2516ra                      1    1B
# 5  RWS01_MONIBAS_0071hrr2516ra                      1    2B
# 6  RWS01_MONIBAS_0071hrr2516ra                      1    3B
# 7  RWS01_MONIBAS_0071hrr2516ra                      1    4B
# 8  RWS01_MONIBAS_0071hrr2516ra                      1    9B
# 9  RWS01_MONIBAS_0071hrr2516ra                      1   10B
#
#            periodstart            periodend numberofincompleteinputs  \
# 0  2017-07-30 02:21:00  2017-07-30 02:22:00                     None
# 1  2017-07-30 02:21:00  2017-07-30 02:22:00                     None
# 2  2017-07-30 02:21:00  2017-07-30 02:22:00                     None
# ...
